# %% [markdown]
# # Importando as bibliotecas e o dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

data = pd.read_csv('datasets/video-game-sales-with-ratings/Video_Games_Sales_as_at_22_Dec_2016.csv')
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# ## Informações do dataset

# %% [markdown]
# ### Estatísticas descritivas

# %%
data.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %% [markdown]
# ### Informações gerais

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Coluna 'Genre' e seus respectivos índices

# %%
#0      Sports
#1      Platform
#2      Racing
#3      Role-Playing
#4      Puzzle
#5      Misc
#6      Shooter
#7      Simulation
#8      Action
#9      Fighting
#10     Adventure
#11     Strategy

# %% [markdown]
# ### Coluna 'Platform' e seus respectivos índices

# %%
#0      Wii
#1      NES
#2      GB
#3      DS
#4      X360
#5      PS3
#6      PS2
#7      SNES
#8      GBA
#9      PS4
#10     3DS
#11     N64
#12     PS
#13     XB
#14     PC
#15     2600
#16     PSP
#17     XOne
#19     WiiU
#20     GC
#21     GEN
#22     DC
#23     PSV
#24     SAT
#25     SCD
#26     WS
#27     NG
#28     TG16
#29     3DO
#30     GG
#31     PCFX

# %% [markdown]
# ### Coluna 'Rating' e seus respectivos índices

# %%
#0      E
#1      M
#2      T
#3      E10+
#4      K-A
#5      AO
#6      EC
#7      RP

# %% [markdown]
# ### Anotações imediatas

# %% [markdown]
# A princípio penso em focar nas colunas Genre, Platform, Global_Sales, Critic_Score, User_Score e Rating.

# %% [markdown]
# ## Limpando os dados

# %% [markdown]
# ### Alterando valores da coluna Genre

# %%
generos = data['Genre'].copy()
generos[generos== 'Sports'] =0
generos[generos== 'Platform'] =1
generos[generos== 'Racing'] =2
generos[generos== 'Role-Playing'] =3
generos[generos== 'Puzzle'] =4
generos[generos== 'Misc'] =5
generos[generos== 'Shooter'] =6
generos[generos== 'Simulation'] =7
generos[generos== 'Action'] =8
generos[generos== 'Fighting'] =9
generos[generos== 'Adventure'] =10
generos[generos== 'Strategy'] =11
data['Genre'] = generos

# %% [markdown]
# ### Alterando valores da coluna Platform

# %%
x = data['Platform'].copy()
x[x== 'Wii'] =0
x[x== 'NES'] =1
x[x== 'GB'] =2
x[x== 'DS'] =3
x[x== 'X360'] =4
x[x== 'PS3'] =5
x[x== 'PS2'] =6
x[x== 'SNES'] =7
x[x== 'GBA'] =8
x[x== 'PS4'] =9
x[x== '3DS'] =10
x[x== 'N64'] =11
x[x== 'PS'] =12
x[x== 'XB'] =13
x[x== 'PC'] =14
x[x== '2600'] =15
x[x== 'PSP'] =16
x[x== 'XOne'] =17
x[x== 'WiiU'] =18
x[x== 'GC'] =19
x[x== 'GENc'] =20
x[x== 'DC'] =21
x[x== 'PSV'] =22
x[x== 'SAT'] =23
x[x== 'SCD'] =24
x[x== 'WS'] =25
x[x== 'NG'] =26
x[x== 'TG16'] =27
x[x== '3DO'] =28
x[x== 'GG'] =29
x[x== 'PCFX'] =30
data['Platform'] = x

# %% [markdown]
# ### Alterando valores da coluna Platform

# %%
x = data['Rating'].copy()
x[x== 'E'] =0
x[x== 'M'] =1
x[x== 'T'] =2
x[x== 'E10+'] =3
x[x== 'K-A'] =4
x[x== 'AO'] =5
x[x== 'EC'] =6
x[x== 'RP'] =7
data['Genre'] = x

# %% [markdown]
# ### Retirando colunas dispensáveis

# %%
#data.drop(['Name', 'Year_of_Release', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Critic_Count', 'User_Count', 'Developer'])
data.drop(columns=['Name'])
data.head()
# Out:
#                        Name Platform  Year_of_Release Genre Publisher  \
# 0                Wii Sports        0           2006.0     0  Nintendo
# 1         Super Mario Bros.        1           1985.0   NaN  Nintendo
# 2            Mario Kart Wii        0           2008.0     0  Nintendo
# 3         Wii Sports Resort        0           2009.0     0  Nintendo
# 4  Pokemon Red/Pokemon Blue        2           1996.0   NaN  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# ### Retirando valores duplicados

# %%
plt.plot(generos,data['Global_Sales'], 'ro')
plt.ylabel('Vendas Globais')
plt.ylabel('Gêneros')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(data['Genre'], data['Global_Sales'], test_size=0.33, random_state=42, shuffle=True)

# %%
#clf = GaussianNB()
#clf.fit(X_train, y_train)
